# %% [markdown]
# # Coding Journal 2, Prompt 8

# %%
# Brent Brison
# Doctor Aguichine
# ASTR 19
# 30 January 2024

# %% [markdown]
# Create a Jupyter notebook, import matplotlib and numpy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Write cells that
# 1) create an array x ranging from [0,1] in 100 steps
# 2) that defines functions that return sin(x) and cos(x).

# %%
nSteps = 100
x = np.linspace(0,1,nSteps)

# %%
def sin(x):
    return np.sin(x)

def cos(x):
    return np.cos(x)

# %% [markdown]
# In a new cell use to create a multipanel plot (1 row, 2 columns), plotting sin(x) vs. x in the left panel and cos(x) vs. x in the right panel. Label the panels with sin(x) and cos(x), and save the figure as a PDF.

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
cosX = cos(x)
sinX = sin(x)
ax1.set_title("x vs cos(x)")
ax2.set_title("x vs sin(x)")
ax1.plot(x,cosX)
ax2.plot(x,sinX)
fig.savefig("cj2-8_graph.pdf")
